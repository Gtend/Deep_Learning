# %% [markdown]
# Iris 데이터가 주어졌을 때 붓꽃의 종류를 분류하는 신경망 모델을 구현

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

np.random.seed(100)
tf.random.set_seed(100)

# sklearn에 저장된 데이터를 불러 옵니다.
X, Y = load_iris(return_X_y = True)

# DataFrame으로 변환
df = pd.DataFrame(X, columns=['꽃받침 길이','꽃받침 넓이', '꽃잎 길이', '꽃잎 넓이'])
df['클래스'] = Y

X = df.drop(columns=['클래스'])
Y = df['클래스']

# 학습용 평가용 데이터로 분리합니다
train_X, test_X, train_Y, test_Y = train_test_split(X, Y, test_size=0.2, random_state = 42)

# Dataset 형태로 변환합니다.
train_ds = tf.data.Dataset.from_tensor_slices((train_X.values, train_Y))
train_ds = train_ds.shuffle(len(train_X)).batch(batch_size=5)

"""
1. keras를 활용하여 신경망 모델을 생성합니다.
   3가지 범주를 갖는 label 데이터를 분류하기 위해서 마지막 레이어 노드를 아래와 같이 설정합니다.
"""
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(10, input_dim=4),
    tf.keras.layers.Dense(3, activation='softmax')
    ])

# 학습용 데이터를 바탕으로 모델의 학습을 수행합니다.
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(train_ds, epochs=100, verbose=2)

# 테스트용 데이터를 바탕으로 학습된 모델을 평가합니다.
loss, acc = model.evaluate(test_X, test_Y)

# 테스트용 데이터의 예측값을 구합니다.
predictions = model.predict(test_X)

# 결과를 출력합니다.
print("\n테스트 데이터의 Accuracy 값: ", acc)
for i in range(5):
    print("%d 번째 테스트 데이터의 실제값: %d" % (i, test_Y.iloc[i]))
    print("%d 번째 테스트 데이터의 예측값: %d" % (i, np.argmax(predictions[i])))
# Out:
# Epoch 1/100
# c:\Users\yumin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:85: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 24/24 - 1s - 30ms/step - accuracy: 0.6667 - loss: 1.3134
# Epoch 2/100
# 24/24 - 0s - 2ms/step - accuracy: 0.6750 - loss: 0.7338
# Epoch 3/100
# 24/24 - 0s - 2ms/step - accuracy: 0.6917 - loss: 0.5710
# Epoch 4/100
# 24/24 - 0s - 2ms/step - accuracy: 0.7917 - loss: 0.5349
# Epoch 5/100
# 24/24 - 0s - 2ms/step - accuracy: 0.8250 - loss: 0.5169
# Epoch 6/100
# 24/24 - 0s - 2ms/step - accuracy: 0.7917 - loss: 0.5010
# Epoch 7/100
# 24/24 - 0s - 2ms/step - accuracy: 0.8333 - loss: 0.4924
# Epoch 8/100
# 24/24 - 0s - 1ms/step - accuracy: 0.8500 - loss: 0.4785
# Epoch 9/100
# 24/24 - 0s - 1ms/step - accuracy: 0.8667 - loss: 0.4663
# Epoch 10/100
# 24/24 - 0s - 1ms/step - accuracy: 0.8417 - loss: 0.4553
# Epoch 11/100
# 24/24 - 0s - 1ms/step - accuracy: 0.8917 - loss: 0.4471
# Epoch 12/100
# 24/24 - 0s - 1ms/step - accuracy: 0.8917 - loss: 0.4358
# Epoch 13/100
# 24/24 - 0s - 2ms/step - accuracy: 0.9167 - loss: 0.4278
# Epoch 14/100
# 24/24 - 0s - 2ms/step - accuracy: 0.9167 - loss: 0.4173
# Epoch 15/100
# 24/24 - 0s - 2ms/step - accuracy: 0.9167 - loss: 0.4106
# Epoch 16/100
# 24/24 - 0s - 2ms/step - accuracy: 0.9167 - loss: 0.4022
# Epoch 17/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9000 - loss: 0.4042
# Epoch 18/100
# 24/24 - 0s - 2ms/step - accuracy: 0.9333 - loss: 0.3917
# Epoch 19/100
# 24/24 - 0s - 1ms/step - accuracy: 0.8917 - loss: 0.3826
# Epoch 20/100
# 24/24 - 0s - 2ms/step - accuracy: 0.9083 - loss: 0.3718
# Epoch 21/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9500 - loss: 0.3650
# Epoch 22/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9667 - loss: 0.3589
# Epoch 23/100
# 24/24 - 0s - 2ms/step - accuracy: 0.9500 - loss: 0.3496
# Epoch 24/100
# 24/24 - 0s - 2ms/step - accuracy: 0.9500 - loss: 0.3449
# Epoch 25/100
# 24/24 - 0s - 2ms/step - accuracy: 0.9583 - loss: 0.3373
# Epoch 26/100
# 24/24 - 0s - 2ms/step - accuracy: 0.9500 - loss: 0.3339
# Epoch 27/100
# 24/24 - 0s - 2ms/step - accuracy: 0.9667 - loss: 0.3257
# Epoch 28/100
# 24/24 - 0s - 2ms/step - accuracy: 0.9667 - loss: 0.3181
# Epoch 29/100
# 24/24 - 0s - 2ms/step - accuracy: 0.9667 - loss: 0.3114
# Epoch 30/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9667 - loss: 0.3059
# Epoch 31/100
# 24/24 - 0s - 2ms/step - accuracy: 0.9500 - loss: 0.3044
# Epoch 32/100
# 24/24 - 0s - 2ms/step - accuracy: 0.9750 - loss: 0.2952
# Epoch 33/100
# 24/24 - 0s - 2ms/step - accuracy: 0.9667 - loss: 0.2883
# Epoch 34/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.2857
# Epoch 35/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9667 - loss: 0.2779
# Epoch 36/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9667 - loss: 0.2707
# Epoch 37/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9583 - loss: 0.2682
# Epoch 38/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.2613
# Epoch 39/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.2569
# Epoch 40/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9667 - loss: 0.2523
# Epoch 41/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.2483
# Epoch 42/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9667 - loss: 0.2465
# Epoch 43/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9667 - loss: 0.2382
# Epoch 44/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.2348
# Epoch 45/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9583 - loss: 0.2304
# Epoch 46/100
# 24/24 - 0s - 2ms/step - accuracy: 0.9750 - loss: 0.2263
# Epoch 47/100
# 24/24 - 0s - 2ms/step - accuracy: 0.9750 - loss: 0.2187
# Epoch 48/100
# 24/24 - 0s - 2ms/step - accuracy: 0.9833 - loss: 0.2149
# Epoch 49/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9583 - loss: 0.2168
# Epoch 50/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9583 - loss: 0.2185
# Epoch 51/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.2044
# Epoch 52/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.2021
# Epoch 53/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.2039
# Epoch 54/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.1940
# Epoch 55/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.1898
# Epoch 56/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.1880
# Epoch 57/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.1836
# Epoch 58/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.1831
# Epoch 59/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.1795
# Epoch 60/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.1747
# Epoch 61/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.1741
# Epoch 62/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.1729
# Epoch 63/100
# 24/24 - 0s - 2ms/step - accuracy: 0.9833 - loss: 0.1669
# Epoch 64/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.1639
# Epoch 65/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.1650
# Epoch 66/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.1612
# Epoch 67/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.1588
# Epoch 68/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.1561
# Epoch 69/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.1534
# Epoch 70/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.1513
# Epoch 71/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.1520
# Epoch 72/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.1508
# Epoch 73/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.1496
# Epoch 74/100
# 24/24 - 0s - 2ms/step - accuracy: 0.9833 - loss: 0.1431
# Epoch 75/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.1424
# Epoch 76/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.1419
# Epoch 77/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.1380
# Epoch 78/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9667 - loss: 0.1389
# Epoch 79/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.1362
# Epoch 80/100
# 24/24 - 0s - 2ms/step - accuracy: 0.9833 - loss: 0.1317
# Epoch 81/100
# 24/24 - 0s - 2ms/step - accuracy: 0.9750 - loss: 0.1323
# Epoch 82/100
# 24/24 - 0s - 2ms/step - accuracy: 0.9750 - loss: 0.1327
# Epoch 83/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.1282
# Epoch 84/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.1256
# Epoch 85/100
# 24/24 - 0s - 2ms/step - accuracy: 0.9750 - loss: 0.1297
# Epoch 86/100
# 24/24 - 0s - 2ms/step - accuracy: 0.9833 - loss: 0.1240
# Epoch 87/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.1230
# Epoch 88/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9667 - loss: 0.1256
# Epoch 89/100
# 24/24 - 0s - 2ms/step - accuracy: 0.9833 - loss: 0.1221
# Epoch 90/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9667 - loss: 0.1239
# Epoch 91/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.1196
# Epoch 92/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.1214
# Epoch 93/100
# 24/24 - 0s - 2ms/step - accuracy: 0.9833 - loss: 0.1195
# Epoch 94/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9667 - loss: 0.1169
# Epoch 95/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9750 - loss: 0.1142
# Epoch 96/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9667 - loss: 0.1187
# Epoch 97/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.1149
# Epoch 98/100
# 24/24 - 0s - 2ms/step - accuracy: 0.9750 - loss: 0.1125
# Epoch 99/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.1095
# Epoch 100/100
# 24/24 - 0s - 1ms/step - accuracy: 0.9833 - loss: 0.1105
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9667 - loss: 0.1469
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
#
# 테스트 데이터의 Accuracy 값:  0.9666666388511658
# 0 번째 테스트 데이터의 실제값: 1
# 0 번째 테스트 데이터의 예측값: 1
# 1 번째 테스트 데이터의 실제값: 0
# 1 번째 테스트 데이터의 예측값: 0
# 2 번째 테스트 데이터의 실제값: 2
# 2 번째 테스트 데이터의 예측값: 2
# 3 번째 테스트 데이터의 실제값: 1
# 3 번째 테스트 데이터의 예측값: 1
# 4 번째 테스트 데이터의 실제값: 1
# 4 번째 테스트 데이터의 예측값: 1
